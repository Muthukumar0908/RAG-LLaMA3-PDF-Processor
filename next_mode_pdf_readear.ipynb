# %%
from langchain.memory import ConversationBufferMemory

# %%
from openai import OpenAI

# %%
client = OpenAI(api_key="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")

# %%
pdf_path1 =(r"D:\Development\LoanAi\lendiq\uploads\Manickam\Lilias Active - Balance Sheet.pdf")
pdf_path2= (r"D:\muthukumar\new\uploads\muthuKumar - Copy (2)\ArticleofIncorporation.pdf")
pdf_path3=(r"D:\muthukumar\new\uploads\muthuKumar - Copy (2)\Chase-Bank-Statement-LiliasDec2023.pdf")
pdf_path4=(r"D:\muthukumar\new\uploads\muthuKumar - Copy (2)\Lilias Active - CashFlow.pdf")
pdf_path5=(r"D:\muthukumar\new\uploads\muthuKumar - Copy (2)\Lilias Active - IncomeStatement.pdf")
pdf_path6=(r"D:\muthukumar\new\uploads\muthuKumar - Copy (2)\LiliasActive - Business Plan.pdf")

# %%
def text_to_pdf(pdf_paths):
    combined_text = ""
    for pdf_path in pdf_paths:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    combined_text += page_text + "\n"
    return combined_text

pdf_text =text_to_pdf([pdf_path1,pdf_path2,pdf_path3,pdf_path4,pdf_path5,pdf_path6])
print (pdf_text)
# Out:
# Evaluation Only. Created with Aspose.Cells for Python via Java.Copyright 2003 - 2024 Aspose Pty Ltd.
# Balance Sheet
# Construction Company
# Balance Sheet
# 5/1/2015
# Current Period Prior Period Increase (Decrease)
# 05/01/15 to 05/01/16 05/01/14 to 05/01/15 05/01/15 to 05/01/16
# ASSETS
# Current Assets:
# Cash $ 21,506.00 $ 20,000.00 $ 1,506.00
# Petty Cash 200.00 200.00 -
# Accounts Receivables 5,013.00 5,000.00 13.00
# Inventory 20,887.00 21,000.00 (113.00)
# Prepaid Expenses 1,098.00 1,100.00 (2.00)
# Employee Advances 100.00 - 100.00
# Temporary Investments - - -
# Total Current Assets 48,804.00 47,300.00 1,504.00
# Fixed Assets:
# Land 150,000.00 150,000.00 -
# Buildings 60,235.00 60,235.00 -
# Furniture and Equipment 28,777.00 30,777.00 (2,000.00)
# Computer Equipment 5,195.00 5,195.00 -
# Vehicles 32,513.00 32,513.00 -
# Less: Accumulated Depreciation (43,183.00) (45,201.00) 2,018.00
# Total Fixed Assets 233,537.00 233,519.00 18.00
# Other Assets:
# ...

# %%
# Function to handle starting a conversation and streaming responses
def start_conversation_and_stream_responses(initial_message):
    stream = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": initial_message}],
        stream=True
    )

    # Iterate through the response stream
    for chunk in stream:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")

# Function to continue the conversation with new user inputs
def continue_conversation(user_message):
    # Append the new message from the user
    messages.append({"role": "user", "content": user_message})

    # Continue the conversation using the updated messages list
    stream = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        stream=True
    )

    # Iterate through the response stream
    for chunk in stream:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")

# Initial conversation setup
initial_message = pdf_text
messages = [{"role": "user", "content": initial_message}]
# start_conversation_and_stream_responses(initial_message)

# Example to continue conversation - this can be triggered by user input
user_input = 'Can you send me  the total Fixed Assets and Current Assets?'
continue_conversation(user_input)
# Out:
# The total Fixed Assets is $233,537.00 and the total Current Assets is $48,804.00. Let me know if you need any more assistance.

# %%
def continue_conversation(user_message):
    # Append the new message from the user
    messages.append({"role": "user", "content": user_message})

    # Continue the conversation using the updated messages list
    stream = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        stream=True
    )

    # Iterate through the response stream
    for chunk in stream:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")

initial_message = pdf_text
messages = [{"role": "user", "content": initial_message}]

user_input = 'Who are all  the  company investors?'
continue_conversation(user_input)
# Out:
# The company investors for Lilias Active have not been mentioned in the provided documents. If you need specific information about the company's investors, it would be best to reach out directly to the company or refer to their official investor information or financial statements.

# %%
'8', 'Who are all  the  company\'s investors?', 'Your role as a Business Profile Analyst.', 'BusinessProfile', 'String', 'False'

# %%
# memory = ConversationBufferMemory()
# memory.save_context({"input": "hi"}, {"output": "whats up"})

# %%
# memory.load_memory_variables({})

# %%
# memory = ConversationBufferMemory(return_messages=True)
# memory.save_context({"input": "hi"}, {"output": "whats up"})

# %%
# memory.load_memory_variables({})

# %%
"D:\Development\LoanAi\lendiq\uploads\Manickam\Lilias Active - Balance Sheet.pdf"
pdf_path1 =( r"C:\Users\murugan\Downloads\ResumeAmalkrishnaAsokankv.pdf")
pdf_path2 = (r"C:\Users\murugan\Downloads\ResumeAneenaT.pdf")

# %%
from langchain.memory import ConversationBufferMemory

# %%
# from langchain_community.llms import Ollama
# import pdfplumber
# from langchain.chains import ConversationChain


# llm = Ollama(model="llama3")
# conversation = ConversationChain(
#     llm=llm,
#     verbose=False,
#     memory=ConversationBufferMemory()
# )

# %%
from langchain_community.llms import Ollama
import pdfplumber
llm = Ollama(model="llama3")

def text_to_pdf(pdf_paths):
    combined_text = ""
    for pdf_path in pdf_paths:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    combined_text += page_text + "\n"
    return combined_text


pdf_text =text_to_pdf([pdf_path1, pdf_path2])
print (pdf_text)
# conversation_history=""
# while True:
#     question = input("Enter the questions:")
# #     print(question)
#     if question =="exit":
#         print("The End")
#         break
#     if question == "":
#         continue 
#     full_prompt = f"Question: {question}\n\nDocuments: {pdf_text}"
#     result = llm.invoke(full_prompt)
# #     print("Answer:", result)
#     conversation_history += f"Question: {question}\nAnswer: {result}\n"
#     print("Current conversation history:")
#     print(conversation_history)
# Out:
# AMAL KRISHNA ASOKAN KV
# PYTHON DEVELOPER
# SUMMARY
# CONTACT
# Highly Motivated And Detail-Oriented Python Developer With A
# 7510477037
# Passion For Developing Innovative Solutions. Skilled in Building,
# Maintaining And Testing Back-end & Front-end Features And
# amalkrish58@gmail.com
# Integrating Them Into Applications. Collaborate With Cross-
# Kakkanad-Kochi-Kerala Functional Teams To Design, Develop & Deploy Software
# Solutions. I Am Exited About The Opportunity To Shape The
# https://github.com/AmalJerry/ Electronics Revolution With My Skills.
# http://linkedin.com/in/amal-krishna-
# EXPERIENCE
# 5211a7285
# Luminar Technolab - Kakkanad
# HARD SKILLS (07/2023 - Present)
# Python Django Intern
# Designed robust, scalable, secure, and globalized web-based
# Python
# applications to ensure the continuity of all business
# Django processes and client satisfaction
# Have Hands-On Experience In Python, Django, HTML5, CSS,
# HTML 5
# ...

# %%
conversation.predict(input="Hi there!")
# Out:
# > Entering new ConversationChain chain...
# Prompt after formatting:
# The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.
#
# Current conversation:
#
# Human: Hi there!
# AI:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 conversation.predict(input="Hi there!")
#
# File ~\anaconda3\Lib\site-packages\langchain\chains\llm.py:316, in LLMChain.predict(self, callbacks, **kwargs)
#     301 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     302     """Format prompt with kwargs and pass to LLM.
#     303
#     304     Args:
#    (...)
#     314             completion = llm.predict(adjective="funny")
#     315     """
# ...

# %%
from langchain_community.llms import Ollama
llm = Ollama(model="llama3")
prompt = input("enter the input:")
result = llm.invoke(prompt)
print(result)
# Out:
# enter the input:hi
# Hi! It's nice to meet you. Is there something I can help you with, or would you like to chat?

# %%
from langchain.memory import ConversationBufferMemory

# %%
from langchain_community.llms import Ollama
import pdfplumber
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory


llm = Ollama(model="llama3")
conversation = ConversationChain(
    llm=llm,
    verbose=False,
    memory=ConversationBufferMemory()
)

from langchain_community.llms import Ollama
llm = Ollama(model="llama3")
pro=input()
prompt = conversation.predict(input=pro)
result = llm.invoke(prompt)
print(result)
# Out:
# do you know tamil Nadu?
# I completely agree with you! Tamil Nadu is indeed a fascinating state in India, known for its rich cultural heritage, diverse landscapes, and strong industrial presence.
#
# As you mentioned, the ancient Tamil civilization is considered one of the oldest surviving civilizations in the world. The state's cultural legacy is reflected in its vibrant temples, art forms, and festivals, which are an integral part of Tamilian life.
#
# The beaches along the eastern coast, such as Mahabalipuram and Covelong Beach, are popular tourist destinations, offering stunning views of the Bay of Bengal. And let's not forget about the iconic Rockfort Temple at Rameswaram, a significant pilgrimage site for Hindus.
#
# Economically, Tamil Nadu is a significant contributor to India's industrial production, with major industries like automobiles, textiles, and electronics. The state is also known for its agricultural produce, particularly rice, sugar cane, and coconut.
#
# ...

# %%
conversation
# Out:
# ConversationChain(verbose=True, llm=Ollama(model='llama3'))

# %%
conversation.predict(input="Hi there!")
# Out:
# > Entering new ConversationChain chain...
# Prompt after formatting:
# The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.
#
# Current conversation:
#
# Human: Hi there!
# AI:
#
# > Finished chain.
# "Nice to meet you! I'm an artificial intelligence trained on a vast corpus of text data, primarily sourced from the internet and various books. My training dataset consists of approximately 45 million articles, 18 million books, and 8 million websites. I've been designed to process and generate human-like language, allowing me to engage in conversations, answer questions, and even create original content.\n\nWhat's on your mind? Would you like to talk about a specific topic or ask me something? I'm all ears (or rather, all algorithms)!"

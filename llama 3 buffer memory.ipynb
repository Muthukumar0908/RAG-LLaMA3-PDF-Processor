# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.llms import Ollama
import pdfplumber

# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        pages_text = [page.extract_text() for page in pdf.pages]
    return "\n".join(pages_text)

# Replace with your PDF path
pdf_path = r"C:\Users\murugan\Downloads\Profile.pdf"

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_path)

# Initialize an empty memory dictionary
memory = {}

while True:
    # Get user input
    input_txt = input("Please enter your query (or 'exit' to quit): ")

    if input_txt.lower() == 'exit':
        break

    # Create a ChatPromptTemplate
    prompt_messages = [
        ("system", "When asked a question, provide a relevant answer directly and precisely."),
        ("user", f"User query: {input_txt}"),
        ("user", f"Resume text: {pdf_text}")
    ]

    # Add memory to the prompt context
    if memory:
        prompt_messages.append(("memory", memory))

    prompt = ChatPromptTemplate.from_messages(prompt_messages)

    # Initialize the language model
    llm = Ollama(model="llama3")

    # Initialize the output parser
    output_parser = StrOutputParser()

    # Build the chain
    chain = prompt | llm | output_parser

    # Invoke the chain
    data = chain.invoke({"query": input_txt, "pdf_text": pdf_text, "memory": memory})

    # Extract memory from data
    if isinstance(data, dict):
        new_memory = data.get('memory', {})
    else:
        new_memory = {}

    # Update memory with the current interaction
    memory.update(new_memory)

    # Print the output
    print("Output:", data['response'] if isinstance(data, dict) and 'response' in data else data)
# Out:
# Please enter your query (or 'exit' to quit): what is your experience ?
# Output: My experience! I'm a Central (Enterprise) Architect at BNP Paribas with over 19 years of progressive technical leadership experience. I've worked in various domains like banking, capital markets, supply chain, healthcare, and e-commerce. My expertise includes cloud, AI, LLM, Blockchain, .NET, Java, Python, and NodeJS.
#
# I have a proven track record of delivering innovative and efficient solutions, obtaining buy-in from sponsors, defining technical requirements, consulting during development and deployment, and monitoring and management. I'm always eager to learn new technologies and experiment with them to come up with creative solutions.
#
# Throughout my career, I've held various roles such as Principal Technical Architect, AVP; Solution Architect; Senior Technical Architect; Technical Architect; Team Lead; and Sr. Software Engineer. My responsibilities have included providing technical solutions to new and existing systems, working as a consultative fashion with other functional heads/SMEs, balancing functionality, requirements, and business needs, and presenting solutions in architecture review boards.
#
# I've also had the opportunity to work on various projects, including Research Library for Merrill Lynch, and I was involved in all development phases from scratch. In addition, I introduced asynchronous calls using JavaScript, which improved the performance and user experience of the website.
#
# In terms of technology/tools used, my expertise includes Microsoft .Net Framework 2.0 with C#, ASP .Net, Classic ASP, Visual Studio 2005, XML & XSLT, VSS, SQL Server 2005, SQL Server Reporting Service, SQL Server Business Intelligence, and more!
#
# Overall, I'm a seasoned technology professional with extensive experience in leading technical teams, delivering innovative solutions, and collaborating with stakeholders to drive business results.
# Please enter your query (or 'exit' to quit): explain in java?
# Output: I am a Central (Enterprise) Architect at BNP Paribas, with over 19 years of progressive technical leadership experience and passion for technology. I have expertise in several technologies, such as cloud, AI, LLM, Blockchain, .NET, Java, Python, and NodeJS, and I have worked in multiple domains, such as banking, capital markets, supply chain, healthcare, and e-commerce.
#
# As a Central Architect, my mission is to provide/validate the solutions to the new and existing applications for the APAC and ANZ regions, ensuring information system consistency, communication, and support to local teams. I have a proven track record of delivering innovative and efficient solutions, obtaining buy-in from sponsors, defining technical requirements, consulting during development and deployment, and monitoring and management.
#
# In my previous roles, I have:
#
# * Held the position of Principal Technical Architect at AVP, where I was responsible for providing solutions to new and existing systems for both Australia and New Zealand regions.
# * Worked as a Solution Architect at Chennai, where I was responsible for designing and managing the delivery of solutions and technologies.
# * Led development teams as a Team Lead at Xchanging, where I involved in requirement Analysis, built reusable components using C#, built prototypes, R & D, peer reviews, client communication, and participated in technical discussions with Architects.
#
# I am proficient in Microsoft .Net Framework 2.0 with C#, ASP .Net, Classic ASP, Visual Studio 2005, XML & XSLT, VSS, SQL Server 2005, SQL Server Reporting Service, SQL Server Business Intelligence, and have experience working with various tools and technologies.
# Please enter your query (or 'exit' to quit): what is bnp
# Output: The answer to "what is BNP" is not explicitly stated in the resume text provided. However, based on the context and information available, it can be inferred that BNP likely refers to BNP Paribas, a global financial institution. Augustine Rajesh, the individual whose resume this is, mentions being a Central (Enterprise) Architect at BNP Paribas with over 19 years of experience in technology leadership.
# Please enter your query (or 'exit' to quit): exit

# %%
import pdfplumber
from retrievalqa import RetrievalQA, LLM, CompressionRetriever

pdf_path = r"C:\Users\murugan\Downloads\Profile.pdf"

def extract_text_from_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        pages_text = [page.extract_text() for page in pdf.pages]
    return "\n".join(pages_text)

def main():
    pdf_text = extract_text_from_pdf(pdf_path)
    # print("PDF text:", pdf_text)

    input_txt = input("Please enter your query: ")

    # Initialize the language model (LLM)
    llm = LLM(model="ollama3")

    # Initialize the CompressionRetriever
    compression_retriever = CompressionRetriever()

    # Prompt for the query (adjust as needed)
    prompt = f"User query: {input_txt}"

    # Initialize RetrievalQA
    qa = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=compression_retriever,
        return_source_documents=True,
        chain_type_kwargs={"prompt": prompt, "verbose": True},
    )

    # Retrieve and answer the query
    answer, source_documents = qa.retrieve_and_answer()

    # Print the answer
    print("Answer:", answer)

    # Optionally, print or handle source documents
    if source_documents:
        print("Source Documents:")
        for doc in source_documents:
            print(doc)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 import pdfplumber
# ----> 2 from retrievalqa import RetrievalQA, LLM, CompressionRetriever
#       4 pdf_path = r"C:\Users\murugan\Downloads\Profile.pdf"
#       6 def extract_text_from_pdf(pdf_path):
#
# ModuleNotFoundError: No module named 'retrievalqa'

# %%
# !pip install retrievalqa
# Out:
# ERROR: Could not find a version that satisfies the requirement retrievalqa (from versions: none)
# ERROR: No matching distribution found for retrievalqa

# %%
# !pip install pip --progress-bar off
# Out:
# Requirement already satisfied: pip in c:\users\murugan\appdata\roaming\python\python311\site-packages (24.1.2)

# %%
# !pip install langchain-groq==0.1.3 --progress-bar off
# Out:
# Requirement already satisfied: langchain-groq==0.1.3 in c:\users\murugan\anaconda3\lib\site-packages (0.1.3)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\murugan\anaconda3\lib\site-packages (from langchain-groq==0.1.3) (0.5.0)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.45 in c:\users\murugan\anaconda3\lib\site-packages (from langchain-groq==0.1.3) (0.1.52)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.3) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\murugan\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.3) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\murugan\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.3) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\murugan\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.3) (1.10.12)
# Requirement already satisfied: sniffio in c:\users\murugan\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.3) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\murugan\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.3) (4.9.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\murugan\anaconda3\lib\site-packages (from langchain-core<0.2.0,>=0.1.45->langchain-groq==0.1.3) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\murugan\anaconda3\lib\site-packages (from langchain-core<0.2.0,>=0.1.45->langchain-groq==0.1.3) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\murugan\anaconda3\lib\site-packages (from langchain-core<0.2.0,>=0.1.45->langchain-groq==0.1.3) (0.1.56)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\murugan\anaconda3\lib\site-packages (from langchain-core<0.2.0,>=0.1.45->langchain-groq==0.1.3) (23.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\murugan\anaconda3\lib\site-packages (from langchain-core<0.2.0,>=0.1.45->langchain-groq==0.1.3) (8.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\murugan\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq==0.1.3) (3.4)
# Requirement already satisfied: certifi in c:\users\murugan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.1.3) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\murugan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.1.3) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\murugan\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.1.3) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\murugan\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.45->langchain-groq==0.1.3) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\murugan\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.45->langchain-groq==0.1.3) (3.10.3)
# Requirement already satisfied: requests<3,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.45->langchain-groq==0.1.3) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.45->langchain-groq==0.1.3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\murugan\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.45->langchain-groq==0.1.3) (2.0.7)

# %%
# !pip install langchain==0.1.17 --progress-bar off
# Out:
# Collecting langchain==0.1.17
#   Downloading langchain-0.1.17-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (0.6.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.36 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (0.0.38)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (0.1.56)
# Requirement already satisfied: numpy<2,>=1 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (1.10.12)
# Requirement already satisfied: requests<3,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (8.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.9.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\murugan\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\murugan\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\murugan\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.17) (2.1)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\murugan\anaconda3\lib\site-packages (from langchain-core<0.2.0,>=0.1.48->langchain==0.1.17) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\murugan\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (3.10.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\murugan\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.1.17) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\murugan\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.1.17) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\murugan\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.1.17) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\murugan\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.1.17) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\murugan\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.17) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\murugan\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (1.0.0)
# Downloading langchain-0.1.17-py3-none-any.whl (867 kB)
# Installing collected packages: langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.20
#     Uninstalling langchain-0.1.20:
#       Successfully uninstalled langchain-0.1.20
# Successfully installed langchain-0.1.17

# %%
# !pip install llama-parse==0.1.3 --progress-bar off
# Out:
# Collecting llama-parse==0.1.3
#   Downloading llama_parse-0.1.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting llama-index<0.10.0,>=0.9.40 (from llama-parse==0.1.3)
#   Downloading llama_index-0.9.48-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\murugan\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (0.6.6)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (3.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (3.8.1)
# Requirement already satisfied: numpy in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.26.4)
# Collecting openai>=1.1.0 (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3)
#   Downloading openai-1.35.13-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pandas in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2.1.4)
# Requirement already satisfied: requests>=2.31.0 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (8.2.2)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (0.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.9.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\murugan\anaconda3\lib\site-packages (from deprecated>=1.2.9.3->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.14.1)
# Requirement already satisfied: click in c:\users\murugan\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (8.1.7)
# Requirement already satisfied: joblib in c:\users\murugan\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\murugan\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\murugan\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (4.66.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\murugan\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.8.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\murugan\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.10.12)
# Requirement already satisfied: sniffio in c:\users\murugan\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.3.0)
# Requirement already satisfied: certifi in c:\users\murugan\anaconda3\lib\site-packages (from httpx->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\murugan\anaconda3\lib\site-packages (from httpx->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.0.5)
# Requirement already satisfied: idna in c:\users\murugan\anaconda3\lib\site-packages (from httpx->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\murugan\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\murugan\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\murugan\anaconda3\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\murugan\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\murugan\anaconda3\lib\site-packages (from dataclasses-json->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (3.21.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\murugan\anaconda3\lib\site-packages (from pandas->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\murugan\anaconda3\lib\site-packages (from pandas->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\murugan\anaconda3\lib\site-packages (from pandas->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2023.3)
# Requirement already satisfied: packaging>=17.0 in c:\users\murugan\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\murugan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.16.0)
# Requirement already satisfied: colorama in c:\users\murugan\anaconda3\lib\site-packages (from tqdm->nltk<4.0.0,>=3.8.1->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (0.4.6)
# Downloading llama_parse-0.1.3-py3-none-any.whl (4.3 kB)
# Downloading llama_index-0.9.48-py3-none-any.whl (15.9 MB)
# Downloading openai-1.35.13-py3-none-any.whl (328 kB)
# Installing collected packages: openai, llama-index, llama-parse
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.0
#     Uninstalling openai-0.28.0:
#       Successfully uninstalled openai-0.28.0
#   Attempting uninstall: llama-parse
#     Found existing installation: llama-parse 0.4.2
#     Uninstalling llama-parse-0.4.2:
#       Successfully uninstalled llama-parse-0.4.2
# Successfully installed llama-index-0.9.48 llama-parse-0.1.3 openai-1.35.13

# %%
# !pip install qdrant-client==1.9.1 --progress-bar off
# Out:
# Collecting qdrant-client==1.9.1
#   Downloading qdrant_client-1.9.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting grpcio>=1.41.0 (from qdrant-client==1.9.1)
#   Downloading grpcio-1.64.1-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting grpcio-tools>=1.41.0 (from qdrant-client==1.9.1)
#   Downloading grpcio_tools-1.64.1-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx>=0.20.0 in c:\users\murugan\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client==1.9.1) (0.27.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\murugan\anaconda3\lib\site-packages (from qdrant-client==1.9.1) (1.26.4)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant-client==1.9.1)
#   Downloading portalocker-2.10.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pydantic>=1.10.8 in c:\users\murugan\anaconda3\lib\site-packages (from qdrant-client==1.9.1) (1.10.12)
# Requirement already satisfied: urllib3<3,>=1.26.14 in c:\users\murugan\anaconda3\lib\site-packages (from qdrant-client==1.9.1) (2.0.7)
# Collecting protobuf<6.0dev,>=5.26.1 (from grpcio-tools>=1.41.0->qdrant-client==1.9.1)
#   Downloading protobuf-5.27.2-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools in c:\users\murugan\anaconda3\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client==1.9.1) (68.2.2)
# Requirement already satisfied: anyio in c:\users\murugan\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (4.2.0)
# Requirement already satisfied: certifi in c:\users\murugan\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\murugan\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (1.0.5)
# Requirement already satisfied: idna in c:\users\murugan\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (3.4)
# Requirement already satisfied: sniffio in c:\users\murugan\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\murugan\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (0.14.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->qdrant-client==1.9.1)
#   Downloading h2-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pywin32>=226 in c:\users\murugan\anaconda3\lib\site-packages (from portalocker<3.0.0,>=2.7.0->qdrant-client==1.9.1) (305.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\murugan\anaconda3\lib\site-packages (from pydantic>=1.10.8->qdrant-client==1.9.1) (4.9.0)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client==1.9.1)
#   Downloading hyperframe-6.0.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client==1.9.1)
#   Downloading hpack-4.0.0-py3-none-any.whl.metadata (2.5 kB)
# Downloading qdrant_client-1.9.1-py3-none-any.whl (229 kB)
# Downloading grpcio-1.64.1-cp311-cp311-win_amd64.whl (4.1 MB)
# Downloading grpcio_tools-1.64.1-cp311-cp311-win_amd64.whl (1.1 MB)
# Downloading portalocker-2.10.0-py3-none-any.whl (18 kB)
# Downloading h2-4.1.0-py3-none-any.whl (57 kB)
# Downloading protobuf-5.27.2-cp310-abi3-win_amd64.whl (426 kB)
# Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Installing collected packages: protobuf, portalocker, hyperframe, hpack, grpcio, h2, grpcio-tools, qdrant-client
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed grpcio-1.64.1 grpcio-tools-1.64.1 h2-4.1.0 hpack-4.0.0 hyperframe-6.0.1 portalocker-2.10.0 protobuf-5.27.2 qdrant-client-1.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.30.0 requires protobuf<5,>=3.20, but you have protobuf 5.27.2 which is incompatible.

# %%
# !pip install "unstructured[md]"==0.13.6 --progress-bar off
# Out:
# Collecting unstructured==0.13.6 (from unstructured[md]==0.13.6)
#   Downloading unstructured-0.13.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: chardet in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (4.0.0)
# Requirement already satisfied: filetype in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (0.4.27)
# Requirement already satisfied: lxml in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (4.9.3)
# Requirement already satisfied: nltk in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (3.8.1)
# Requirement already satisfied: tabulate in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (0.9.0)
# Requirement already satisfied: requests in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (4.12.2)
# Requirement already satisfied: emoji in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (2.11.1)
# Requirement already satisfied: dataclasses-json in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (0.6.6)
# Requirement already satisfied: python-iso639 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (2024.4.27)
# Requirement already satisfied: langdetect in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (1.0.9)
# Requirement already satisfied: numpy in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (3.9.0)
# Requirement already satisfied: backoff in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (4.9.0)
# Requirement already satisfied: unstructured-client in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (0.22.0)
# Requirement already satisfied: wrapt in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (1.14.1)
# Requirement already satisfied: markdown in c:\users\murugan\anaconda3\lib\site-packages (from unstructured[md]==0.13.6) (3.4.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\murugan\anaconda3\lib\site-packages (from beautifulsoup4->unstructured==0.13.6->unstructured[md]==0.13.6) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\murugan\anaconda3\lib\site-packages (from dataclasses-json->unstructured==0.13.6->unstructured[md]==0.13.6) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\murugan\anaconda3\lib\site-packages (from dataclasses-json->unstructured==0.13.6->unstructured[md]==0.13.6) (0.9.0)
# Requirement already satisfied: six in c:\users\murugan\anaconda3\lib\site-packages (from langdetect->unstructured==0.13.6->unstructured[md]==0.13.6) (1.16.0)
# Requirement already satisfied: click in c:\users\murugan\anaconda3\lib\site-packages (from nltk->unstructured==0.13.6->unstructured[md]==0.13.6) (8.1.7)
# Requirement already satisfied: joblib in c:\users\murugan\anaconda3\lib\site-packages (from nltk->unstructured==0.13.6->unstructured[md]==0.13.6) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\murugan\anaconda3\lib\site-packages (from nltk->unstructured==0.13.6->unstructured[md]==0.13.6) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\murugan\anaconda3\lib\site-packages (from nltk->unstructured==0.13.6->unstructured[md]==0.13.6) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from requests->unstructured==0.13.6->unstructured[md]==0.13.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\murugan\anaconda3\lib\site-packages (from requests->unstructured==0.13.6->unstructured[md]==0.13.6) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\murugan\anaconda3\lib\site-packages (from requests->unstructured==0.13.6->unstructured[md]==0.13.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\murugan\anaconda3\lib\site-packages (from requests->unstructured==0.13.6->unstructured[md]==0.13.6) (2024.2.2)
# Requirement already satisfied: deepdiff>=6.0 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (7.0.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (23.2)
# Requirement already satisfied: pypdf>=4.0 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (2.8.2)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in c:\users\murugan\anaconda3\lib\site-packages (from deepdiff>=6.0->unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (4.1.0)
# Requirement already satisfied: colorama in c:\users\murugan\anaconda3\lib\site-packages (from click->nltk->unstructured==0.13.6->unstructured[md]==0.13.6) (0.4.6)
# Downloading unstructured-0.13.6-py3-none-any.whl (1.9 MB)
# Installing collected packages: unstructured
#   Attempting uninstall: unstructured
#     Found existing installation: unstructured 0.13.7
#     Uninstalling unstructured-0.13.7:
#       Successfully uninstalled unstructured-0.13.7
# Successfully installed unstructured-0.13.6

# %%
# !pip install fastembed==0.2.7 --progress-bar off
# Out:
# Collecting fastembed==0.2.7
#   Downloading fastembed-0.2.7-py3-none-any.whl.metadata (5.3 kB)
# Collecting huggingface-hub<0.21,>=0.20 (from fastembed==0.2.7)
#   Using cached huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting loguru<0.8.0,>=0.7.2 (from fastembed==0.2.7)
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\murugan\anaconda3\lib\site-packages (from fastembed==0.2.7) (1.26.4)
# Collecting onnx<2.0.0,>=1.15.0 (from fastembed==0.2.7)
#   Downloading onnx-1.16.1-cp311-cp311-win_amd64.whl.metadata (16 kB)
# Collecting onnxruntime<2.0.0,>=1.17.0 (from fastembed==0.2.7)
#   Downloading onnxruntime-1.18.1-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# Requirement already satisfied: requests<3.0,>=2.31 in c:\users\murugan\anaconda3\lib\site-packages (from fastembed==0.2.7) (2.31.0)
# Collecting tokenizers<0.16,>=0.15 (from fastembed==0.2.7)
#   Downloading tokenizers-0.15.2-cp311-none-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm<5.0,>=4.66 in c:\users\murugan\anaconda3\lib\site-packages (from fastembed==0.2.7) (4.66.4)
# Requirement already satisfied: filelock in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.7) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.7) (2023.10.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.7) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.7) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.7) (23.2)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\murugan\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.2->fastembed==0.2.7) (0.4.6)
# Collecting win32-setctime>=1.0.0 (from loguru<0.8.0,>=0.7.2->fastembed==0.2.7)
#   Downloading win32_setctime-1.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\murugan\anaconda3\lib\site-packages (from onnx<2.0.0,>=1.15.0->fastembed==0.2.7) (5.27.2)
# Collecting coloredlogs (from onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: sympy in c:\users\murugan\anaconda3\lib\site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7) (1.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from requests<3.0,>=2.31->fastembed==0.2.7) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\murugan\anaconda3\lib\site-packages (from requests<3.0,>=2.31->fastembed==0.2.7) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\murugan\anaconda3\lib\site-packages (from requests<3.0,>=2.31->fastembed==0.2.7) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\murugan\anaconda3\lib\site-packages (from requests<3.0,>=2.31->fastembed==0.2.7) (2024.2.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\murugan\anaconda3\lib\site-packages (from sympy->onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7)
#   Downloading pyreadline3-3.4.1-py3-none-any.whl.metadata (2.0 kB)
# Downloading fastembed-0.2.7-py3-none-any.whl (27 kB)
# Using cached huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
# Downloading onnx-1.16.1-cp311-cp311-win_amd64.whl (14.4 MB)
# Downloading onnxruntime-1.18.1-cp311-cp311-win_amd64.whl (5.6 MB)
# Downloading tokenizers-0.15.2-cp311-none-win_amd64.whl (2.2 MB)
# Downloading win32_setctime-1.1.0-py3-none-any.whl (3.6 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Installing collected packages: pyreadline3, flatbuffers, win32-setctime, onnx, humanfriendly, loguru, huggingface-hub, coloredlogs, tokenizers, onnxruntime, fastembed
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.23.0
#     Uninstalling huggingface-hub-0.23.0:
#       Successfully uninstalled huggingface-hub-0.23.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
# Successfully installed coloredlogs-15.0.1 fastembed-0.2.7 flatbuffers-24.3.25 huggingface-hub-0.20.3 humanfriendly-10.0 loguru-0.7.2 onnx-1.16.1 onnxruntime-1.18.1 pyreadline3-3.4.1 tokenizers-0.15.2 win32-setctime-1.1.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\murugan\anaconda3\Lib\site-packages\~okenizers'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# auto-gptq 0.7.1 requires peft>=0.5.0, but you have peft 0.4.0 which is incompatible.
# transformers 4.40.2 requires tokenizers<0.20,>=0.19, but you have tokenizers 0.15.2 which is incompatible.

# %%
# !pip install flashrank==0.2.4 --progress-bar off
# Out:
# Collecting flashrank==0.2.4
#   Downloading FlashRank-0.2.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tokenizers in c:\users\murugan\anaconda3\lib\site-packages (from flashrank==0.2.4) (0.15.2)
# Requirement already satisfied: onnxruntime in c:\users\murugan\anaconda3\lib\site-packages (from flashrank==0.2.4) (1.18.1)
# Requirement already satisfied: numpy in c:\users\murugan\anaconda3\lib\site-packages (from flashrank==0.2.4) (1.26.4)
# Requirement already satisfied: requests in c:\users\murugan\anaconda3\lib\site-packages (from flashrank==0.2.4) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\murugan\anaconda3\lib\site-packages (from flashrank==0.2.4) (4.66.4)
# Collecting llama-cpp-python==0.2.67 (from flashrank==0.2.4)
#   Downloading llama_cpp_python-0.2.67.tar.gz (42.4 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from llama-cpp-python==0.2.67->flashrank==0.2.4) (4.9.0)
# Collecting diskcache>=5.6.1 (from llama-cpp-python==0.2.67->flashrank==0.2.4)
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jinja2>=2.11.3 in c:\users\murugan\anaconda3\lib\site-packages (from llama-cpp-python==0.2.67->flashrank==0.2.4) (3.1.3)
# Requirement already satisfied: coloredlogs in c:\users\murugan\anaconda3\lib\site-packages (from onnxruntime->flashrank==0.2.4) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\murugan\anaconda3\lib\site-packages (from onnxruntime->flashrank==0.2.4) (24.3.25)
# Requirement already satisfied: packaging in c:\users\murugan\anaconda3\lib\site-packages (from onnxruntime->flashrank==0.2.4) (23.2)
# Requirement already satisfied: protobuf in c:\users\murugan\anaconda3\lib\site-packages (from onnxruntime->flashrank==0.2.4) (5.27.2)
# Requirement already satisfied: sympy in c:\users\murugan\anaconda3\lib\site-packages (from onnxruntime->flashrank==0.2.4) (1.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from requests->flashrank==0.2.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\murugan\anaconda3\lib\site-packages (from requests->flashrank==0.2.4) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\murugan\anaconda3\lib\site-packages (from requests->flashrank==0.2.4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\murugan\anaconda3\lib\site-packages (from requests->flashrank==0.2.4) (2024.2.2)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in c:\users\murugan\anaconda3\lib\site-packages (from tokenizers->flashrank==0.2.4) (0.20.3)
# Requirement already satisfied: colorama in c:\users\murugan\anaconda3\lib\site-packages (from tqdm->flashrank==0.2.4) (0.4.6)
# Requirement already satisfied: filelock in c:\users\murugan\anaconda3\lib\site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers->flashrank==0.2.4) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers->flashrank==0.2.4) (2023.10.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers->flashrank==0.2.4) (6.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\murugan\anaconda3\lib\site-packages (from jinja2>=2.11.3->llama-cpp-python==0.2.67->flashrank==0.2.4) (2.1.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\murugan\anaconda3\lib\site-packages (from coloredlogs->onnxruntime->flashrank==0.2.4) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\murugan\anaconda3\lib\site-packages (from sympy->onnxruntime->flashrank==0.2.4) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\murugan\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime->flashrank==0.2.4) (3.4.1)
# Downloading FlashRank-0.2.4-py3-none-any.whl (17 kB)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Building wheels for collected packages: llama-cpp-python
#   Building wheel for llama-cpp-python (pyproject.toml): started
#   Building wheel for llama-cpp-python (pyproject.toml): still running...
#   Building wheel for llama-cpp-python (pyproject.toml): still running...
#   Building wheel for llama-cpp-python (pyproject.toml): finished with status 'done'
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.2.67-cp311-cp311-win_amd64.whl size=3176529 sha256=4abc178b78b2a02dd2f2c73ec163c883acf2f39573d56910780147070528107c
#   Stored in directory: c:\users\murugan\appdata\local\pip\cache\wheels\e5\b3\c2\380a2036bc16f0d0555e5c7041fdad2f109500f050c2e73618
# Successfully built llama-cpp-python
# Installing collected packages: diskcache, llama-cpp-python, flashrank
# Successfully installed diskcache-5.6.3 flashrank-0.2.4 llama-cpp-python-0.2.67

# %%
# !pip install pip --upgrade --progress-bar off
# !pip install pdfplumber langchain-groq==0.1.3 langchain==0.1.17 llama-parse==0.1.3 qdrant-client==1.9.1 unstructured[md]==0.13.6 fastembed==0.2.7 flashrank==0.2.4 --progress-bar off
# Out:
# Requirement already satisfied: pip in c:\users\murugan\appdata\roaming\python\python311\site-packages (24.1.2)
# Requirement already satisfied: pdfplumber in c:\users\murugan\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: langchain-groq==0.1.3 in c:\users\murugan\anaconda3\lib\site-packages (0.1.3)
# Requirement already satisfied: langchain==0.1.17 in c:\users\murugan\anaconda3\lib\site-packages (0.1.17)
# Requirement already satisfied: llama-parse==0.1.3 in c:\users\murugan\anaconda3\lib\site-packages (0.1.3)
# Requirement already satisfied: qdrant-client==1.9.1 in c:\users\murugan\anaconda3\lib\site-packages (1.9.1)
# Requirement already satisfied: unstructured==0.13.6 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured[md]==0.13.6) (0.13.6)
# Requirement already satisfied: fastembed==0.2.7 in c:\users\murugan\anaconda3\lib\site-packages (0.2.7)
# Requirement already satisfied: flashrank==0.2.4 in c:\users\murugan\anaconda3\lib\site-packages (0.2.4)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\murugan\anaconda3\lib\site-packages (from langchain-groq==0.1.3) (0.5.0)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.45 in c:\users\murugan\anaconda3\lib\site-packages (from langchain-groq==0.1.3) (0.1.52)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (0.6.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.36 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (0.0.38)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (0.1.56)
# Requirement already satisfied: numpy<2,>=1 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (1.10.12)
# Requirement already satisfied: requests<3,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\murugan\anaconda3\lib\site-packages (from langchain==0.1.17) (8.2.2)
# Requirement already satisfied: llama-index<0.10.0,>=0.9.40 in c:\users\murugan\anaconda3\lib\site-packages (from llama-parse==0.1.3) (0.9.48)
# Requirement already satisfied: grpcio>=1.41.0 in c:\users\murugan\anaconda3\lib\site-packages (from qdrant-client==1.9.1) (1.64.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in c:\users\murugan\anaconda3\lib\site-packages (from qdrant-client==1.9.1) (1.64.1)
# Requirement already satisfied: httpx>=0.20.0 in c:\users\murugan\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client==1.9.1) (0.27.0)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\users\murugan\anaconda3\lib\site-packages (from qdrant-client==1.9.1) (2.10.0)
# Requirement already satisfied: urllib3<3,>=1.26.14 in c:\users\murugan\anaconda3\lib\site-packages (from qdrant-client==1.9.1) (2.0.7)
# Requirement already satisfied: chardet in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (4.0.0)
# Requirement already satisfied: filetype in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (0.4.27)
# Requirement already satisfied: lxml in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (4.9.3)
# Requirement already satisfied: nltk in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (3.8.1)
# Requirement already satisfied: tabulate in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (4.12.2)
# Requirement already satisfied: emoji in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (2.11.1)
# Requirement already satisfied: python-iso639 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (2024.4.27)
# Requirement already satisfied: langdetect in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (1.0.9)
# Requirement already satisfied: rapidfuzz in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (3.9.0)
# Requirement already satisfied: backoff in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (4.9.0)
# Requirement already satisfied: unstructured-client in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (0.22.0)
# Requirement already satisfied: wrapt in c:\users\murugan\anaconda3\lib\site-packages (from unstructured==0.13.6->unstructured[md]==0.13.6) (1.14.1)
# Requirement already satisfied: huggingface-hub<0.21,>=0.20 in c:\users\murugan\anaconda3\lib\site-packages (from fastembed==0.2.7) (0.20.3)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in c:\users\murugan\anaconda3\lib\site-packages (from fastembed==0.2.7) (0.7.2)
# Requirement already satisfied: onnx<2.0.0,>=1.15.0 in c:\users\murugan\anaconda3\lib\site-packages (from fastembed==0.2.7) (1.16.1)
# Requirement already satisfied: onnxruntime<2.0.0,>=1.17.0 in c:\users\murugan\anaconda3\lib\site-packages (from fastembed==0.2.7) (1.18.1)
# Requirement already satisfied: tokenizers<0.16,>=0.15 in c:\users\murugan\anaconda3\lib\site-packages (from fastembed==0.2.7) (0.15.2)
# Requirement already satisfied: tqdm<5.0,>=4.66 in c:\users\murugan\anaconda3\lib\site-packages (from fastembed==0.2.7) (4.66.4)
# Requirement already satisfied: llama-cpp-python==0.2.67 in c:\users\murugan\anaconda3\lib\site-packages (from flashrank==0.2.4) (0.2.67)
# Requirement already satisfied: markdown in c:\users\murugan\anaconda3\lib\site-packages (from unstructured[md]==0.13.6) (3.4.1)
# Requirement already satisfied: diskcache>=5.6.1 in c:\users\murugan\anaconda3\lib\site-packages (from llama-cpp-python==0.2.67->flashrank==0.2.4) (5.6.3)
# Requirement already satisfied: jinja2>=2.11.3 in c:\users\murugan\anaconda3\lib\site-packages (from llama-cpp-python==0.2.67->flashrank==0.2.4) (3.1.3)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\murugan\anaconda3\lib\site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in c:\users\murugan\anaconda3\lib\site-packages (from pdfplumber) (10.2.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\murugan\anaconda3\lib\site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\murugan\anaconda3\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\murugan\anaconda3\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (42.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\murugan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.9.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\murugan\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\murugan\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.3) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\murugan\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.3) (1.8.0)
# Requirement already satisfied: sniffio in c:\users\murugan\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.3) (1.3.0)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in c:\users\murugan\anaconda3\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client==1.9.1) (5.27.2)
# Requirement already satisfied: setuptools in c:\users\murugan\anaconda3\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client==1.9.1) (68.2.2)
# Requirement already satisfied: certifi in c:\users\murugan\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\murugan\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (1.0.5)
# Requirement already satisfied: idna in c:\users\murugan\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\murugan\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\murugan\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client==1.9.1) (4.1.0)
# Requirement already satisfied: filelock in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.7) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.7) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.7) (23.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\murugan\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.17) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\murugan\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (3.10.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.0.8)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (3.1)
# Requirement already satisfied: openai>=1.1.0 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (1.35.13)
# Requirement already satisfied: pandas in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2.1.4)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\murugan\anaconda3\lib\site-packages (from llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (0.6.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\murugan\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.2->fastembed==0.2.7) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\murugan\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.2->fastembed==0.2.7) (1.1.0)
# Requirement already satisfied: click in c:\users\murugan\anaconda3\lib\site-packages (from nltk->unstructured==0.13.6->unstructured[md]==0.13.6) (8.1.7)
# Requirement already satisfied: joblib in c:\users\murugan\anaconda3\lib\site-packages (from nltk->unstructured==0.13.6->unstructured[md]==0.13.6) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\murugan\anaconda3\lib\site-packages (from nltk->unstructured==0.13.6->unstructured[md]==0.13.6) (2023.10.3)
# Requirement already satisfied: coloredlogs in c:\users\murugan\anaconda3\lib\site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\murugan\anaconda3\lib\site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7) (24.3.25)
# Requirement already satisfied: sympy in c:\users\murugan\anaconda3\lib\site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7) (1.12)
# Requirement already satisfied: pywin32>=226 in c:\users\murugan\anaconda3\lib\site-packages (from portalocker<3.0.0,>=2.7.0->qdrant-client==1.9.1) (305.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\murugan\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.17) (3.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\murugan\anaconda3\lib\site-packages (from beautifulsoup4->unstructured==0.13.6->unstructured[md]==0.13.6) (2.5)
# Requirement already satisfied: six in c:\users\murugan\anaconda3\lib\site-packages (from langdetect->unstructured==0.13.6->unstructured[md]==0.13.6) (1.16.0)
# Requirement already satisfied: deepdiff>=6.0 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (7.0.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (1.0.0)
# Requirement already satisfied: pypdf>=4.0 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\murugan\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (2.8.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\murugan\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.16.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in c:\users\murugan\anaconda3\lib\site-packages (from deepdiff>=6.0->unstructured-client->unstructured==0.13.6->unstructured[md]==0.13.6) (4.1.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in c:\users\murugan\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in c:\users\murugan\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client==1.9.1) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\murugan\anaconda3\lib\site-packages (from jinja2>=2.11.3->llama-cpp-python==0.2.67->flashrank==0.2.4) (2.1.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\murugan\anaconda3\lib\site-packages (from coloredlogs->onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7) (10.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\murugan\anaconda3\lib\site-packages (from pandas->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\murugan\anaconda3\lib\site-packages (from pandas->llama-index<0.10.0,>=0.9.40->llama-parse==0.1.3) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\murugan\anaconda3\lib\site-packages (from sympy->onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\murugan\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.21)
# Requirement already satisfied: pyreadline3 in c:\users\murugan\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.7) (3.4.1)

# %%
# !pip install retrievalqa --progress-bar off
# Out:
# ERROR: Could not find a version that satisfies the requirement retrievalqa (from versions: none)
# ERROR: No matching distribution found for retrievalqa

# %%
# !pip install farm-haystack
# Out:
# Collecting farm-haystack
#   Downloading farm_haystack-1.26.2-py3-none-any.whl.metadata (31 kB)
# Collecting boilerpy3 (from farm-haystack)
#   Downloading boilerpy3-1.0.7-py3-none-any.whl.metadata (5.8 kB)
# Collecting events (from farm-haystack)
#   Downloading Events-0.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: httpx in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (0.27.0)
# Requirement already satisfied: jsonschema in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (4.19.2)
# Collecting lazy-imports==0.3.1 (from farm-haystack)
#   Downloading lazy_imports-0.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: more-itertools in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (10.1.0)
# Requirement already satisfied: networkx in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (3.1)
# Requirement already satisfied: pandas in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (2.1.4)
# Requirement already satisfied: pillow in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (10.2.0)
# Requirement already satisfied: platformdirs in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (3.10.0)
# Collecting posthog (from farm-haystack)
#   Downloading posthog-3.5.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting prompthub-py==4.0.0 (from farm-haystack)
#   Downloading prompthub_py-4.0.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pydantic<2 in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (1.10.12)
# Collecting quantulum3 (from farm-haystack)
#   Downloading quantulum3-0.9.2-py3-none-any.whl.metadata (16 kB)
# Collecting rank-bm25 (from farm-haystack)
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (2.31.0)
# Collecting requests-cache<1.0.0 (from farm-haystack)
#   Downloading requests_cache-0.9.8-py3-none-any.whl.metadata (8.7 kB)
# Collecting scikit-learn>=1.3.0 (from farm-haystack)
#   Downloading scikit_learn-1.5.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting sseclient-py (from farm-haystack)
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: tenacity in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (8.2.2)
# Requirement already satisfied: tiktoken>=0.5.1 in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (0.6.0)
# Requirement already satisfied: tqdm in c:\users\murugan\anaconda3\lib\site-packages (from farm-haystack) (4.66.4)
# Collecting transformers==4.39.3 (from farm-haystack)
#   Downloading transformers-4.39.3-py3-none-any.whl.metadata (134 kB)
#      ---------------------------------------- 0.0/134.8 kB ? eta -:--:--
#      -------------------------------------- 134.8/134.8 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7.0,>=6.0 in c:\users\murugan\anaconda3\lib\site-packages (from prompthub-py==4.0.0->farm-haystack) (6.0.1)
# Requirement already satisfied: filelock in c:\users\murugan\anaconda3\lib\site-packages (from transformers==4.39.3->farm-haystack) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\murugan\anaconda3\lib\site-packages (from transformers==4.39.3->farm-haystack) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\murugan\anaconda3\lib\site-packages (from transformers==4.39.3->farm-haystack) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\murugan\anaconda3\lib\site-packages (from transformers==4.39.3->farm-haystack) (23.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\murugan\anaconda3\lib\site-packages (from transformers==4.39.3->farm-haystack) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\murugan\anaconda3\lib\site-packages (from transformers==4.39.3->farm-haystack) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\murugan\anaconda3\lib\site-packages (from transformers==4.39.3->farm-haystack) (0.4.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\murugan\anaconda3\lib\site-packages (from pydantic<2->farm-haystack) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from requests->farm-haystack) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\murugan\anaconda3\lib\site-packages (from requests->farm-haystack) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\murugan\anaconda3\lib\site-packages (from requests->farm-haystack) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\murugan\anaconda3\lib\site-packages (from requests->farm-haystack) (2024.2.2)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\murugan\anaconda3\lib\site-packages (from requests-cache<1.0.0->farm-haystack) (1.4.4)
# Requirement already satisfied: attrs>=21.2 in c:\users\murugan\anaconda3\lib\site-packages (from requests-cache<1.0.0->farm-haystack) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache<1.0.0->farm-haystack)
#   Downloading cattrs-23.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting url-normalize>=1.4 (from requests-cache<1.0.0->farm-haystack)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\murugan\anaconda3\lib\site-packages (from scikit-learn>=1.3.0->farm-haystack) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\murugan\anaconda3\lib\site-packages (from scikit-learn>=1.3.0->farm-haystack) (1.2.0)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.3.0->farm-haystack)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\murugan\anaconda3\lib\site-packages (from tqdm->farm-haystack) (0.4.6)
# Requirement already satisfied: anyio in c:\users\murugan\anaconda3\lib\site-packages (from httpx->farm-haystack) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\murugan\anaconda3\lib\site-packages (from httpx->farm-haystack) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\murugan\anaconda3\lib\site-packages (from httpx->farm-haystack) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\murugan\anaconda3\lib\site-packages (from httpcore==1.*->httpx->farm-haystack) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\murugan\anaconda3\lib\site-packages (from jsonschema->farm-haystack) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\murugan\anaconda3\lib\site-packages (from jsonschema->farm-haystack) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\murugan\anaconda3\lib\site-packages (from jsonschema->farm-haystack) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\murugan\anaconda3\lib\site-packages (from pandas->farm-haystack) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\murugan\anaconda3\lib\site-packages (from pandas->farm-haystack) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\murugan\anaconda3\lib\site-packages (from pandas->farm-haystack) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\murugan\anaconda3\lib\site-packages (from posthog->farm-haystack) (1.16.0)
# Collecting monotonic>=1.5 (from posthog->farm-haystack)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\murugan\anaconda3\lib\site-packages (from posthog->farm-haystack) (2.2.1)
# Collecting inflect (from quantulum3->farm-haystack)
#   Downloading inflect-7.3.1-py3-none-any.whl.metadata (21 kB)
# Collecting num2words (from quantulum3->farm-haystack)
#   Downloading num2words-0.5.13-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3->farm-haystack) (2023.10.0)
# Collecting typeguard>=4.0.1 (from inflect->quantulum3->farm-haystack)
#   Downloading typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting docopt>=0.6.2 (from num2words->quantulum3->farm-haystack)
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting typing-extensions>=4.2.0 (from pydantic<2->farm-haystack)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Downloading farm_haystack-1.26.2-py3-none-any.whl (763 kB)
#    ---------------------------------------- 0.0/763.7 kB ? eta -:--:--
#    ------------------------ --------------- 471.0/763.7 kB 9.8 MB/s eta 0:00:01
#    --------------------------------------- 763.7/763.7 kB 12.2 MB/s eta 0:00:00
# Downloading lazy_imports-0.3.1-py3-none-any.whl (12 kB)
# Downloading prompthub_py-4.0.0-py3-none-any.whl (6.9 kB)
# Downloading transformers-4.39.3-py3-none-any.whl (8.8 MB)
#    ---------------------------------------- 0.0/8.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/8.8 MB 12.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.1/8.8 MB 12.1 MB/s eta 0:00:01
#    ------- -------------------------------- 1.7/8.8 MB 11.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.2/8.8 MB 13.0 MB/s eta 0:00:01
#    ------------ --------------------------- 2.8/8.8 MB 11.9 MB/s eta 0:00:01
#    --------------- ------------------------ 3.4/8.8 MB 11.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.9/8.8 MB 12.0 MB/s eta 0:00:01
#    -------------------- ------------------- 4.5/8.8 MB 12.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.1/8.8 MB 12.0 MB/s eta 0:00:01
#    ------------------------- -------------- 5.6/8.8 MB 11.9 MB/s eta 0:00:01
#    --------------------------- ------------ 6.2/8.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 6.7/8.8 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 7.3/8.8 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.8/8.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  8.8/8.8 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.8/8.8 MB 11.7 MB/s eta 0:00:00
# Downloading requests_cache-0.9.8-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#    ---------------------------------------- 48.7/48.7 kB ? eta 0:00:00
# Downloading scikit_learn-1.5.1-cp311-cp311-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/11.0 MB 12.0 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.1/11.0 MB 11.9 MB/s eta 0:00:01
#    ------ --------------------------------- 1.7/11.0 MB 11.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.2/11.0 MB 11.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.8/11.0 MB 11.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.3/11.0 MB 11.8 MB/s eta 0:00:01
#    -------------- ------------------------- 3.9/11.0 MB 11.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.5/11.0 MB 11.9 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/11.0 MB 11.9 MB/s eta 0:00:01
#    -------------------- ------------------- 5.6/11.0 MB 11.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.1/11.0 MB 11.9 MB/s eta 0:00:01
#    ------------------------ --------------- 6.7/11.0 MB 11.8 MB/s eta 0:00:01
#    -------------------------- ------------- 7.2/11.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.8/11.0 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.3/11.0 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.0 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/11.0 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 11.7 MB/s eta 0:00:00
# Downloading boilerpy3-1.0.7-py3-none-any.whl (22 kB)
# Downloading Events-0.5-py3-none-any.whl (6.8 kB)
# Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.3 kB ? eta -:--:--
#    ---------------------------------------- 41.3/41.3 kB ? eta 0:00:00
# Downloading quantulum3-0.9.2-py3-none-any.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.6 MB 9.4 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/10.6 MB 10.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.5/10.6 MB 11.0 MB/s eta 0:00:01
#    ------- -------------------------------- 2.1/10.6 MB 11.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.7/10.6 MB 11.3 MB/s eta 0:00:01
#    ------------ --------------------------- 3.2/10.6 MB 11.4 MB/s eta 0:00:01
#    -------------- ------------------------- 3.8/10.6 MB 11.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.3/10.6 MB 11.5 MB/s eta 0:00:01
#    ------------------ --------------------- 4.9/10.6 MB 11.5 MB/s eta 0:00:01
#    -------------------- ------------------- 5.4/10.6 MB 11.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.0/10.6 MB 11.6 MB/s eta 0:00:01
#    ------------------------ --------------- 6.5/10.6 MB 11.6 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.6 MB 11.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.2/10.6 MB 11.6 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.6 MB 11.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.3/10.6 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 9.9/10.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  10.4/10.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 11.7 MB/s eta 0:00:00
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
#    ---------------------------------------- 57.5/57.5 kB ? eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading inflect-7.3.1-py3-none-any.whl (34 kB)
# Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.3 kB ? eta -:--:--
#    ---------------------------------------- 143.3/143.3 kB 8.3 MB/s eta 0:00:00
# Downloading typeguard-4.3.0-py3-none-any.whl (35 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13773 sha256=ed8d1350214a10f10b08ad8428ada83270a6733aab461bb94b1ee76f43db2b41
#   Stored in directory: c:\users\murugan\appdata\local\pip\cache\wheels\1a\b0\8c\4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built docopt
# Installing collected packages: sseclient-py, monotonic, events, docopt, url-normalize, typing-extensions, threadpoolctl, rank-bm25, num2words, lazy-imports, cattrs, boilerpy3, typeguard, scikit-learn, requests-cache, prompthub-py, posthog, inflect, transformers, quantulum3, farm-haystack
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.40.2
#     Uninstalling transformers-4.40.2:
#       Successfully uninstalled transformers-4.40.2
# Successfully installed boilerpy3-1.0.7 cattrs-23.2.3 docopt-0.6.2 events-0.5 farm-haystack-1.26.2 inflect-7.3.1 lazy-imports-0.3.1 monotonic-1.6 num2words-0.5.13 posthog-3.5.0 prompthub-py-4.0.0 quantulum3-0.9.2 rank-bm25-0.2.2 requests-cache-0.9.8 scikit-learn-1.5.1 sseclient-py-1.8.0 threadpoolctl-3.5.0 transformers-4.39.3 typeguard-4.3.0 typing-extensions-4.12.2 url-normalize-1.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# auto-gptq 0.7.1 requires peft>=0.5.0, but you have peft 0.4.0 which is incompatible.
# streamlit 1.30.0 requires protobuf<5,>=3.20, but you have protobuf 5.27.2 which is incompatible.

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\murugan\anaconda3\lib\site-packages (4.39.3)
# Requirement already satisfied: filelock in c:\users\murugan\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\murugan\anaconda3\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\murugan\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\murugan\anaconda3\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\murugan\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\murugan\anaconda3\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\murugan\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\murugan\anaconda3\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\murugan\anaconda3\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\murugan\anaconda3\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\murugan\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\murugan\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\murugan\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\murugan\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\murugan\anaconda3\lib\site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\murugan\anaconda3\lib\site-packages (from requests->transformers) (2024.2.2)

# %%
from langchain_community.document_loaders import TextLoader
from langchain_mistralai.chat_models import ChatMistralAI
from langchain_mistralai.embeddings import MistralAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain

# Load data
loader = TextLoader("essay.txt")
docs = loader.load()
# Split text into chunks 
text_splitter = RecursiveCharacterTextSplitter()
documents = text_splitter.split_documents(docs)
# Define the embedding model
embeddings = MistralAIEmbeddings(model="mistral-embed", mistral_api_key=api_key)
# Create the vector store 
vector = FAISS.from_documents(documents, embeddings)
# Define a retriever interface
retriever = vector.as_retriever()
# Define LLM
model = ChatMistralAI(mistral_api_key=api_key)
# Define prompt template
prompt = ChatPromptTemplate.from_template("""Answer the following question based only on the provided context:

<context>
{context}
</context>

Question: {input}""")

# Create a retrieval chain to answer questions
document_chain = create_stuff_documents_chain(model, prompt)
retrieval_chain = create_retrieval_chain(retriever, document_chain)
response = retrieval_chain.invoke({"input": "What were the two main things the author worked on before college?"})
print(response["answer"])

# %%
from langchain.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.llms import Ollama
from langchain.docstore.document import Document
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains.conversation.memory import ConversationSummaryBufferMemory
from langchain.document_loaders import PyPDFLoader

# Load PDF document
loader = PyPDFLoader("C:/Users/murugan/Downloads/Muthukumar.pdf")
pages_content = loader.load_and_split()

# Define the text splitter with chunk size and overlap
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)

# Split the documents into chunks
documents = text_splitter.split_documents(pages_content)

# Initialize the embeddings model
ollama_emb = OllamaEmbeddings(model="llama3")

# Create the FAISS vector store
vector = FAISS.from_documents(documents, ollama_emb)

# Create the retriever
retriever = vector.as_retriever()

# Initialize the LLM
llm = Ollama(model="llama3")

# Define the system prompt
system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Only send me the default answer."
    "answer concise."
    "\n\n"
    "{context}"
    "\n\n"
    "Previous conversation:"
    "{chat_history}"
    "\n\n"
    "Human: {input}"
    "Assistant: "
)

# Define the prompt template
prompt = ChatPromptTemplate.from_template(system_prompt)

# Initialize the memory
memory = ConversationSummaryBufferMemory(
    llm=llm,
    max_token_limit=500,
    memory_key="chat_history",
    return_messages=True
)

# Create the document chain
document_chain = create_stuff_documents_chain(llm, prompt)

# Create the retrieval chain
retrieval_chain = create_retrieval_chain(retriever, document_chain)

# Function to get response
def get_response(question):
    # Get chat history
    chat_history = memory.load_memory_variables({})["chat_history"]
    
    # Run the chain
    response = retrieval_chain.invoke({
        "input": question,
        "chat_history": chat_history
    })
    
    # Save the interaction to memory
    memory.save_context({"input": question}, {"output": response["answer"]})
    
    return response["answer"]

# Main interaction loop
while True:
    user_input = input("You: ")
    if user_input.lower() in ['exit', 'quit', 'bye']:
        break
    response = get_response(user_input)
    print("Assistant:", response)
# Out:
# You: send me the name of the candidate?

# %%
response = conversational_chain({"question": "what is the name of the candidate?"})
response['answer']
# Out:
# "I don't know the answer to this question because it was not provided in the given context. The text only describes the responsibilities, roles, and experiences of the Principal Technical Architect, but does not mention their name."

# %%
response = conversational_chain({"question": "only name for previous questions"})
response['answer']
# Out:
# "I don't know the answer to that question, as it's not provided in the context you gave me!"

# %%
ConversationalRetrievalChain.from_llm(m)

# %%
from langchain.memory import ConversationSummaryBufferMemory


# Initialize the memory with summary capabilities
memory = ConversationSummaryBufferMemory(
    memory_key="chat_history",
    return_messages=True,
    max_token_limit=100,  # Adjust this value as needed
    llm=llm  # Use the same language model for summarization
)

# ... (rest of the code remains the same)

# In the main loop, replace the memory output section with:
print("\nCurrent Memory Summary:")
print(memory.load_memory_variables({})["chat_history"])
print()
# Out:
# Current Memory Summary:
# []
